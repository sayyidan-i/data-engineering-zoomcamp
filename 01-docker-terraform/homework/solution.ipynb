# %% [markdown]
# ### Q1

# %% [markdown]
# --rm

# %% [markdown]
# ### Q2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 0.42.0

# %% [markdown]
# ### Q3
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q4
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q6
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q7
# ![image.png](attachment:image.png)
